# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from tensorflow.python import keras
from tensorflow.keras.layers import BatchNormalization
from tensorflow.python.keras.models import Sequential
from tensorflow.keras.layers import MaxPool2D
import tensorflow.keras.utils 
from tensorflow.keras.utils import to_categorical
from keras import utils as np_utils
from tensorflow.python.keras.layers import Dense, Flatten, Conv2D, Dropout, MaxPooling2D
from keras.utils.vis_utils import model_to_dot
from keras.utils import np_utils
import seaborn as sn
import matplotlib.pyplot as plt
from keras import backend as K

# %%
pip install visualkeras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (1.21.6)
# Collecting aggdraw>=1.3.11
#   Downloading aggdraw-1.3.15-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (989 kB)
#      |████████████████████████████████| 989 kB 34.8 MB/s
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (7.1.2)
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.15 visualkeras-0.0.2

# %%
import visualkeras

# %%
## Important functions 

## -------------------------------------------------------------------- ##

def F1_Score(y_true, y_pred): 
  true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
  possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
  predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
  precision = true_positives / (predicted_positives + K.epsilon())
  recall = true_positives / (possible_positives + K.epsilon())
  f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
  return f1_val

## -------------------------------------------------------------------- ##
def preprocessing(raw, num_classes, im_rows, im_columns):
  out_y = tensorflow.keras.utils.to_categorical(raw.label, num_classes)
  num_images = raw.shape[0]
  x_as_array = raw.values[:,1:]
  x_reshaped = x_as_array.reshape(num_images, im_rows, im_columns, 1)
  normalized_x = x_reshaped / 255

  return normalized_x, out_y

# %%
train_file = '/content/drive/MyDrive/Neural Networks & Deep Learning/FashionMNIST/fashion-mnist_train.csv'
test_file = '/content/drive/MyDrive/Neural Networks & Deep Learning/FashionMNIST/fashion-mnist_test.csv'
train_data = pd.read_csv(train_file)
test_data = pd.read_csv(test_file)

# %%
num_classes = 10
im_rows = 28
im_columns = 28

# %%
x_train, y_train = preprocessing(train_data, 10, 28, 28)

# %%
def MakeModel():
  model = Sequential()
  model.add( Conv2D(filters= 64, kernel_size=(5,5), padding='Same',activation='relu', input_shape=(28,28,1)) )
  model.add(BatchNormalization())
  
  model.add( Conv2D(filters= 64, kernel_size=(4,4), padding='Same',activation='relu') )
  model.add(BatchNormalization())
  
  model.add( MaxPool2D(pool_size=(3,3)) )
  model.add(Dropout(0.4))

  model.add( Conv2D(filters=128, kernel_size=(4,4), padding='Same',activation='relu') )
  model.add(BatchNormalization())
  model.add( Conv2D(filters=128, kernel_size=(3,3), padding='Same',activation='relu') )
  model.add(BatchNormalization())
  model.add( MaxPool2D(pool_size=(2,2)) )
  model.add(Dropout(0.4))
  
  model.add( Conv2D(filters=256, kernel_size=(4,4), padding='Same',activation='relu') )
  model.add(BatchNormalization())
  model.add( Conv2D(filters=256, kernel_size=(3,3), padding='Same',activation='relu') )
  model.add(BatchNormalization())
  model.add( MaxPool2D(pool_size=(2,2)) )
  model.add(Dropout(0.4))

  model.add( Conv2D(filters=512, kernel_size=(4,4), padding='Same',activation='relu') )
  model.add(BatchNormalization())
  model.add( Conv2D(filters=512, kernel_size=(3,3), padding='Same',activation='relu') )
  model.add(BatchNormalization())
  model.add( MaxPool2D(pool_size=(2,2)) )
  model.add(Dropout(0.4))

  
  model.add(Flatten())
  
  model.add(Dense(1024,activation='relu'))
  model.add(BatchNormalization())
  model.add(Dense(num_classes,activation='softmax'))
  
  model.summary()
  return model

# %%
model = MakeModel()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 28, 28, 64)        1664
# _________________________________________________________________
# module_wrapper_26 (ModuleWra (None, 28, 28, 64)        256
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 28, 28, 64)        65600
# _________________________________________________________________
# module_wrapper_27 (ModuleWra (None, 28, 28, 64)        256
# _________________________________________________________________
# module_wrapper_28 (ModuleWra (None, 9, 9, 64)          0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 9, 9, 64)          0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 9, 9, 128)         131200
# _________________________________________________________________
# module_wrapper_29 (ModuleWra (None, 9, 9, 128)         512
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 9, 9, 128)         147584
# _________________________________________________________________
# module_wrapper_30 (ModuleWra (None, 9, 9, 128)         512
# _________________________________________________________________
# module_wrapper_31 (ModuleWra (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 4, 4, 256)         524544
# _________________________________________________________________
# module_wrapper_32 (ModuleWra (None, 4, 4, 256)         1024
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 4, 4, 256)         590080
# _________________________________________________________________
# module_wrapper_33 (ModuleWra (None, 4, 4, 256)         1024
# _________________________________________________________________
# module_wrapper_34 (ModuleWra (None, 2, 2, 256)         0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 2, 2, 512)         2097664
# _________________________________________________________________
# module_wrapper_35 (ModuleWra (None, 2, 2, 512)         2048
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# module_wrapper_36 (ModuleWra (None, 2, 2, 512)         2048
# _________________________________________________________________
# module_wrapper_37 (ModuleWra (None, 1, 1, 512)         0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# module_wrapper_38 (ModuleWra (None, 1024)              4096
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 6,465,482
# Trainable params: 6,459,594
# Non-trainable params: 5,888
# _________________________________________________________________

# %%
visualkeras.layered_view(model, to_file='output.png', legend = True)
# Out:
# <PIL.Image.Image image mode=RGBA size=1289x186 at 0x7FAAE6D8D110>

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy',F1_Score])

# %%
history=model.fit(x_train, y_train, batch_size=64, epochs=50, validation_split=0.25)
# Out:
# Epoch 1/50
# 704/704 [==============================] - 20s 25ms/step - loss: 0.6369 - accuracy: 0.7710 - F1_Score: 0.7696 - val_loss: 0.4251 - val_accuracy: 0.8496 - val_F1_Score: 0.8519
# Epoch 2/50
# 704/704 [==============================] - 18s 26ms/step - loss: 0.3847 - accuracy: 0.8620 - F1_Score: 0.8626 - val_loss: 0.3201 - val_accuracy: 0.8904 - val_F1_Score: 0.8918
# Epoch 3/50
# 704/704 [==============================] - 18s 25ms/step - loss: 0.3284 - accuracy: 0.8828 - F1_Score: 0.8829 - val_loss: 0.2989 - val_accuracy: 0.8974 - val_F1_Score: 0.8988
# Epoch 4/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.3026 - accuracy: 0.8923 - F1_Score: 0.8926 - val_loss: 0.2901 - val_accuracy: 0.8928 - val_F1_Score: 0.8945
# Epoch 5/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.2791 - accuracy: 0.9006 - F1_Score: 0.9009 - val_loss: 0.2485 - val_accuracy: 0.9129 - val_F1_Score: 0.9132
# Epoch 6/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.2589 - accuracy: 0.9069 - F1_Score: 0.9071 - val_loss: 0.2911 - val_accuracy: 0.8956 - val_F1_Score: 0.8956
# Epoch 7/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.2586 - accuracy: 0.9063 - F1_Score: 0.9066 - val_loss: 0.2457 - val_accuracy: 0.9118 - val_F1_Score: 0.9133
# Epoch 8/50
# 704/704 [==============================] - 18s 26ms/step - loss: 0.2369 - accuracy: 0.9143 - F1_Score: 0.9147 - val_loss: 0.2418 - val_accuracy: 0.9131 - val_F1_Score: 0.9135
# Epoch 9/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.2250 - accuracy: 0.9192 - F1_Score: 0.9196 - val_loss: 0.2341 - val_accuracy: 0.9151 - val_F1_Score: 0.9167
# Epoch 10/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.2178 - accuracy: 0.9213 - F1_Score: 0.9219 - val_loss: 0.2501 - val_accuracy: 0.9158 - val_F1_Score: 0.9175
# Epoch 11/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.2029 - accuracy: 0.9261 - F1_Score: 0.9268 - val_loss: 0.2592 - val_accuracy: 0.9041 - val_F1_Score: 0.9049
# Epoch 12/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.1984 - accuracy: 0.9293 - F1_Score: 0.9292 - val_loss: 0.2199 - val_accuracy: 0.9235 - val_F1_Score: 0.9241
# Epoch 13/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.1792 - accuracy: 0.9354 - F1_Score: 0.9363 - val_loss: 0.2493 - val_accuracy: 0.9115 - val_F1_Score: 0.9130
# Epoch 14/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.1764 - accuracy: 0.9363 - F1_Score: 0.9366 - val_loss: 0.2182 - val_accuracy: 0.9251 - val_F1_Score: 0.9249
# Epoch 15/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.1647 - accuracy: 0.9409 - F1_Score: 0.9413 - val_loss: 0.2178 - val_accuracy: 0.9252 - val_F1_Score: 0.9264
# Epoch 16/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.1570 - accuracy: 0.9425 - F1_Score: 0.9433 - val_loss: 0.2137 - val_accuracy: 0.9295 - val_F1_Score: 0.9307
# Epoch 17/50
# 704/704 [==============================] - 18s 26ms/step - loss: 0.1545 - accuracy: 0.9450 - F1_Score: 0.9451 - val_loss: 0.1986 - val_accuracy: 0.9316 - val_F1_Score: 0.9324
# Epoch 18/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.1436 - accuracy: 0.9473 - F1_Score: 0.9478 - val_loss: 0.1995 - val_accuracy: 0.9319 - val_F1_Score: 0.9332
# Epoch 19/50
# 704/704 [==============================] - 18s 26ms/step - loss: 0.1420 - accuracy: 0.9492 - F1_Score: 0.9487 - val_loss: 0.2252 - val_accuracy: 0.9258 - val_F1_Score: 0.9264
# Epoch 20/50
# 704/704 [==============================] - 18s 26ms/step - loss: 0.1334 - accuracy: 0.9518 - F1_Score: 0.9519 - val_loss: 0.2164 - val_accuracy: 0.9305 - val_F1_Score: 0.9305
# Epoch 21/50
# 704/704 [==============================] - 18s 26ms/step - loss: 0.1297 - accuracy: 0.9532 - F1_Score: 0.9531 - val_loss: 0.2175 - val_accuracy: 0.9293 - val_F1_Score: 0.9302
# Epoch 22/50
# 704/704 [==============================] - 18s 26ms/step - loss: 0.1372 - accuracy: 0.9498 - F1_Score: 0.9503 - val_loss: 0.2102 - val_accuracy: 0.9323 - val_F1_Score: 0.9324
# Epoch 23/50
# 704/704 [==============================] - 18s 26ms/step - loss: 0.1142 - accuracy: 0.9580 - F1_Score: 0.9583 - val_loss: 0.2211 - val_accuracy: 0.9284 - val_F1_Score: 0.9289
# Epoch 24/50
# 704/704 [==============================] - 18s 26ms/step - loss: 0.1109 - accuracy: 0.9600 - F1_Score: 0.9601 - val_loss: 0.2072 - val_accuracy: 0.9331 - val_F1_Score: 0.9333
# Epoch 25/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.1059 - accuracy: 0.9610 - F1_Score: 0.9608 - val_loss: 0.1990 - val_accuracy: 0.9342 - val_F1_Score: 0.9342
# Epoch 26/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.1058 - accuracy: 0.9610 - F1_Score: 0.9614 - val_loss: 0.2030 - val_accuracy: 0.9381 - val_F1_Score: 0.9385
# Epoch 27/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.1025 - accuracy: 0.9627 - F1_Score: 0.9629 - val_loss: 0.2118 - val_accuracy: 0.9339 - val_F1_Score: 0.9352
# Epoch 28/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.1036 - accuracy: 0.9623 - F1_Score: 0.9623 - val_loss: 0.2295 - val_accuracy: 0.9313 - val_F1_Score: 0.9319
# Epoch 29/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.0913 - accuracy: 0.9670 - F1_Score: 0.9672 - val_loss: 0.2276 - val_accuracy: 0.9328 - val_F1_Score: 0.9331
# Epoch 30/50
# 704/704 [==============================] - 18s 25ms/step - loss: 0.0912 - accuracy: 0.9672 - F1_Score: 0.9673 - val_loss: 0.2147 - val_accuracy: 0.9380 - val_F1_Score: 0.9384
# Epoch 31/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.0853 - accuracy: 0.9695 - F1_Score: 0.9693 - val_loss: 0.2052 - val_accuracy: 0.9349 - val_F1_Score: 0.9354
# Epoch 32/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.0828 - accuracy: 0.9696 - F1_Score: 0.9697 - val_loss: 0.2199 - val_accuracy: 0.9357 - val_F1_Score: 0.9360
# Epoch 33/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.0809 - accuracy: 0.9698 - F1_Score: 0.9698 - val_loss: 0.2390 - val_accuracy: 0.9359 - val_F1_Score: 0.9369
# Epoch 34/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.0790 - accuracy: 0.9714 - F1_Score: 0.9713 - val_loss: 0.2387 - val_accuracy: 0.9335 - val_F1_Score: 0.9338
# Epoch 35/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.0745 - accuracy: 0.9730 - F1_Score: 0.9731 - val_loss: 0.2242 - val_accuracy: 0.9365 - val_F1_Score: 0.9374
# Epoch 36/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.0756 - accuracy: 0.9720 - F1_Score: 0.9718 - val_loss: 0.2291 - val_accuracy: 0.9357 - val_F1_Score: 0.9363
# Epoch 37/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.0757 - accuracy: 0.9726 - F1_Score: 0.9727 - val_loss: 0.2260 - val_accuracy: 0.9332 - val_F1_Score: 0.9336
# Epoch 38/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.0689 - accuracy: 0.9747 - F1_Score: 0.9746 - val_loss: 0.2278 - val_accuracy: 0.9380 - val_F1_Score: 0.9383
# Epoch 39/50
# 704/704 [==============================] - 18s 25ms/step - loss: 0.0680 - accuracy: 0.9757 - F1_Score: 0.9755 - val_loss: 0.2535 - val_accuracy: 0.9359 - val_F1_Score: 0.9367
# Epoch 40/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.0713 - accuracy: 0.9747 - F1_Score: 0.9748 - val_loss: 0.2415 - val_accuracy: 0.9361 - val_F1_Score: 0.9364
# Epoch 41/50
# 704/704 [==============================] - 18s 25ms/step - loss: 0.0613 - accuracy: 0.9784 - F1_Score: 0.9784 - val_loss: 0.2486 - val_accuracy: 0.9347 - val_F1_Score: 0.9351
# Epoch 42/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.0635 - accuracy: 0.9770 - F1_Score: 0.9770 - val_loss: 0.2279 - val_accuracy: 0.9360 - val_F1_Score: 0.9365
# Epoch 43/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.0602 - accuracy: 0.9787 - F1_Score: 0.9789 - val_loss: 0.2592 - val_accuracy: 0.9337 - val_F1_Score: 0.9343
# Epoch 44/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.0568 - accuracy: 0.9788 - F1_Score: 0.9789 - val_loss: 0.2513 - val_accuracy: 0.9362 - val_F1_Score: 0.9366
# Epoch 45/50
# 704/704 [==============================] - 18s 25ms/step - loss: 0.0564 - accuracy: 0.9792 - F1_Score: 0.9792 - val_loss: 0.2447 - val_accuracy: 0.9375 - val_F1_Score: 0.9379
# Epoch 46/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.0553 - accuracy: 0.9802 - F1_Score: 0.9801 - val_loss: 0.2710 - val_accuracy: 0.9338 - val_F1_Score: 0.9345
# Epoch 47/50
# 704/704 [==============================] - 18s 25ms/step - loss: 0.0548 - accuracy: 0.9802 - F1_Score: 0.9801 - val_loss: 0.2461 - val_accuracy: 0.9361 - val_F1_Score: 0.9367
# Epoch 48/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.0538 - accuracy: 0.9806 - F1_Score: 0.9807 - val_loss: 0.2573 - val_accuracy: 0.9342 - val_F1_Score: 0.9344
# Epoch 49/50
# 704/704 [==============================] - 18s 25ms/step - loss: 0.0526 - accuracy: 0.9808 - F1_Score: 0.9809 - val_loss: 0.2669 - val_accuracy: 0.9349 - val_F1_Score: 0.9350
# Epoch 50/50
# 704/704 [==============================] - 17s 24ms/step - loss: 0.0499 - accuracy: 0.9822 - F1_Score: 0.9823 - val_loss: 0.2782 - val_accuracy: 0.9351 - val_F1_Score: 0.9358

# %%
plt.style.use('classic')
plt.plot(history.history['loss'],'red')
plt.plot(history.history['val_loss'],'blue')
plt.title('Loss vs. Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['loss', 'val_loss'])
plt.figure(figsize=(5,3))

# %%
plt.style.use('classic')
plt.plot(history.history['accuracy'],'red')
plt.plot(history.history['val_accuracy'],'blue')
plt.title('Accuracy vs. Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['accuracy', 'val_accuracy'], loc='lower right')

plt.figure(figsize=(5,3))

# %%
plt.style.use('classic')
plt.plot(history.history['F1_Score'],'red')
plt.plot(history.history['val_F1_Score'],'blue')
plt.title('F1 score vs. Epoch')
plt.xlabel('Epoch')
plt.ylabel('F1 score')
plt.legend(['F1_Score', 'val_F1_Score'], loc = 'lower right')
plt.figure(figsize=(5,3))

# %%
x_test, y_test = preprocessing(test_data, 10, 28, 28)

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.26205044984817505
# Test accuracy: 0.9355999827384949

# %%
#get the predictions for the test data
predicted_classes = model.predict_classes(x_test)
#get the indices to be plotted
y_true = np.array(test_data.iloc[:, 0])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:454: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
accurate_pred = np.nonzero(predicted_classes == y_true)[0]
non_accurate_pred = np.nonzero(predicted_classes != y_true)[0]

# %%
print(classification_report(predicted_classes, y_true))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.89      1006
#            1       1.00      0.99      0.99      1011
#            2       0.86      0.94      0.90       915
#            3       0.95      0.91      0.93      1045
#            4       0.90      0.92      0.91       973
#            5       0.98      0.99      0.99       981
#            6       0.83      0.79      0.81      1049
#            7       0.98      0.96      0.97      1022
#            8       0.99      0.99      0.99      1000
#            9       0.97      0.98      0.98       998
#
#     accuracy                           0.94     10000
#    macro avg       0.94      0.94      0.94     10000
# weighted avg       0.94      0.94      0.94     10000

# %%
labels = {0 : "T-shirt/top", 
          1: "Trouser", 
          2: "Pullover", 
          3: "Dress", 
          4: "Coat",
          5: "Sandal", 
          6: "Shirt", 
          7: "Sneaker", 
          8: "Bag", 
          9: "Ankle Boot"}
target_names = ["Class {} ({}) :".format(i,labels[i]) for i in range(num_classes)]
cf = confusion_matrix(np.array(y_true), predicted_classes)
df_cm = pd.DataFrame(cf, index = [i for i in target_names],
                  columns = [i for i in target_names])
plt.figure(figsize = (12,9))
sn.heatmap(df_cm, annot=True)
